# %% [markdown]
# <a href="https://colab.research.google.com/github/BeriberT/ejercicio-git-1/blob/main/Ejemplo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Condicionales**
#
# un condicional puede ser simple o doble
#
# EJ:

# %%
n= 5345258345
Res = n % 2
if Res == 0:
  print(n, "es par")
else:
  print(n, "es impar ")
# Out:
# 5345258345 es impar
